# %% [markdown]
# Import library

# %%
import numpy as np
import torch
import torch.nn as nn
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import torch.nn.functional as F
import torch.nn.init as init
import matplotlib.pyplot as plt
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
import torchvision
import torchvision.transforms as transforms

# %% [markdown]
# Download training dataset

# %%
# transform = transforms.Compose([transforms.Resize(28),
#                                 transforms.ToTensor(),
#                                 transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
#                                 transforms.Grayscale(num_output_channels=1),])

# train_set = datasets.CIFAR10(root='./datasets', train=True, download=True, transform=transform)
# test_set = datasets.CIFAR10(root='./datasets', train=False, download=True, transform=transform)

# train_loader = DataLoader(train_set, shuffle=True, batch_size=64, pin_memory=True)
# test_loader = DataLoader(test_set, shuffle=False, batch_size=64, pin_memory=True)

# Load CFashionMNIST dataset
transform = transforms.Compose([transforms.Resize(28), transforms.ToTensor(), transforms.Normalize((0,), (1.0/255.0,))])

trainset = torchvision.datasets.FashionMNIST(root='data', train=True, download=True, transform=transform)
train_loader = torch.utils.data.DataLoader(trainset, batch_size=1024, num_workers=10, shuffle=True, pin_memory=True, drop_last=True, persistent_workers=True)

testset = torchvision.datasets.FashionMNIST(root='data', train=False, download=True, transform=transform)
test_loader = torch.utils.data.DataLoader(testset, batch_size=1024, num_workers=10, shuffle=False, pin_memory=True, drop_last=True, persistent_workers=True)
# Out:
# 100%|██████████| 26.4M/26.4M [00:02<00:00, 12.7MB/s]
# 100%|██████████| 29.5k/29.5k [00:00<00:00, 197kB/s]
# 100%|██████████| 4.42M/4.42M [00:01<00:00, 3.73MB/s]
# 100%|██████████| 5.15k/5.15k [00:00<00:00, 19.5MB/s]
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 10 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(

# %% [markdown]
# Define MoE sparse

# %%
class NoisyTopKRouter(nn.Module):
    def __init__(self, n_embed, num_experts, top_k):
        super(NoisyTopKRouter, self).__init__()
        self.top_k = top_k

        self.topkrouter_linear = nn.Linear(n_embed, num_experts)
        self.noise_linear = nn.Linear(n_embed, num_experts)

    def forward(self, x):
        logits = self.topkrouter_linear(x)
        # noise logits
        noise_logits = self.noise_linear(x)

        # add noise
        noise = torch.randn_like(logits)*F.softplus(noise_logits)
        noisy_logits = logits + noise

        # take top_k
        top_k_logits, indices = noisy_logits.topk(self.top_k, dim=-1)
        zeros = torch.full_like(noisy_logits, float('-inf'))
        sparse_logits = zeros.scatter(-1, indices, top_k_logits)
        router_output = F.softmax(sparse_logits, dim=-1)
        return router_output


class SpareMoE(nn.Module):
    def __init__(self, n_embed, num_experts, top_k, hidden_dim):
        super(SpareMoE, self).__init__()
        self.router = NoisyTopKRouter(n_embed, num_experts, top_k)

        self.experts = nn.ModuleList([
            nn.Sequential(
                nn.Linear(28*28, hidden_dim),
                nn.GELU(),
                nn.Linear(hidden_dim, hidden_dim),
                nn.GELU(),
                nn.Linear(hidden_dim, 10)
            ) for _ in range(num_experts)
        ])
        self.flatten = nn.Flatten()

    def forward(self, x):

        x = self.flatten(x)
        # get expert weight via router
        expert_weight = self.router(x)

        # get output of each expert
        expert_outputs = torch.stack([expert(x) for expert in self.experts])
        # combine expert outputs weighted by gate outputs
        output = torch.sum(expert_outputs*expert_weight.t().unsqueeze(-1), dim=0)

        return output

moe_model = SpareMoE(n_embed=28*28, num_experts=10, top_k=5, hidden_dim=20).to(device)

moe_model
# Out:
# SpareMoE(
#   (router): NoisyTopKRouter(
#     (topkrouter_linear): Linear(in_features=784, out_features=10, bias=True)
#     (noise_linear): Linear(in_features=784, out_features=10, bias=True)
#   )
#   (experts): ModuleList(
#     (0-9): 10 x Sequential(
#       (0): Linear(in_features=784, out_features=20, bias=True)
#       (1): GELU(approximate='none')
#       (2): Linear(in_features=20, out_features=20, bias=True)
#       (3): GELU(approximate='none')
#       (4): Linear(in_features=20, out_features=10, bias=True)
#     )
#   )
#   (flatten): Flatten(start_dim=1, end_dim=-1)
# )

# %% [markdown]
# Train

# %%
# Function to compute loss and accuracy for test set
def evaluate(model, testloader, criterion):
    model.eval()
    test_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        for images, labels in testloader:
            # Move inputs and labels to the device
            images, labels = images.to(device), labels.to(device)

            outputs = model(images)
            loss = criterion(outputs, labels)
            test_loss += loss.item()

            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    accuracy = 100 * correct / total
    test_loss = test_loss / len(testloader)
    return test_loss, accuracy

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(moe_model.parameters())
max_epoch = 50

# list to store metrics for ploting
moe_train_losses = []
moe_train_accuracies = []
moe_test_losses = []
moe_test_accuracies = []

# training loop
for epoch in range(max_epoch):
    moe_model.train()
    running_loss = 0.0
    running_correct = 0
    total = 0
    for i, (inputs, labels) in enumerate(train_loader, 0):
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = moe_model(inputs)
        loss = criterion(outputs, labels)

        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        running_correct += (predicted==labels).sum().item()

        loss.backward()
        optimizer.step()
        running_loss += loss.item()

    epoch_accuracy = 100 * running_correct / total
    epoch_loss = running_loss/(i+1)
    test_loss, test_accuracy = evaluate(moe_model, test_loader, criterion)

    print(f"MoE Epoch [{epoch + 1}/{max_epoch}], Loss: {epoch_loss:.4f}, Accuracy: {epoch_accuracy:.2f}%, Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%")

    moe_train_losses.append(epoch_loss)
    moe_train_accuracies.append(epoch_accuracy)
    moe_test_losses.append(test_loss)
    moe_test_accuracies.append(test_accuracy)
# Out:
# MoE Epoch [1/50], Loss: 1.7482, Accuracy: 56.01%, Test Loss: 0.7018, Test Accuracy: 74.83%
# MoE Epoch [2/50], Loss: 0.5933, Accuracy: 78.41%, Test Loss: 0.5705, Test Accuracy: 80.09%
# MoE Epoch [3/50], Loss: 0.5188, Accuracy: 81.32%, Test Loss: 0.5391, Test Accuracy: 81.15%
# MoE Epoch [4/50], Loss: 0.4823, Accuracy: 82.62%, Test Loss: 0.5092, Test Accuracy: 81.91%
# MoE Epoch [5/50], Loss: 0.4668, Accuracy: 83.08%, Test Loss: 0.5124, Test Accuracy: 82.09%
# MoE Epoch [6/50], Loss: 0.4502, Accuracy: 83.75%, Test Loss: 0.4984, Test Accuracy: 82.18%
# MoE Epoch [7/50], Loss: 0.4327, Accuracy: 84.28%, Test Loss: 0.4757, Test Accuracy: 83.75%
# MoE Epoch [8/50], Loss: 0.4232, Accuracy: 84.63%, Test Loss: 0.4750, Test Accuracy: 83.62%
# MoE Epoch [9/50], Loss: 0.4141, Accuracy: 84.96%, Test Loss: 0.4566, Test Accuracy: 83.97%
# MoE Epoch [10/50], Loss: 0.4024, Accuracy: 85.21%, Test Loss: 0.4430, Test Accuracy: 84.54%
# MoE Epoch [11/50], Loss: 0.3947, Accuracy: 85.61%, Test Loss: 0.4526, Test Accuracy: 84.16%
# MoE Epoch [12/50], Loss: 0.3835, Accuracy: 85.94%, Test Loss: 0.4453, Test Accuracy: 84.74%
# MoE Epoch [13/50], Loss: 0.3791, Accuracy: 86.14%, Test Loss: 0.4466, Test Accuracy: 83.79%
# MoE Epoch [14/50], Loss: 0.3858, Accuracy: 85.84%, Test Loss: 0.4257, Test Accuracy: 85.19%
# MoE Epoch [15/50], Loss: 0.3699, Accuracy: 86.40%, Test Loss: 0.4398, Test Accuracy: 84.79%
# MoE Epoch [16/50], Loss: 0.3659, Accuracy: 86.51%, Test Loss: 0.4460, Test Accuracy: 84.62%
# MoE Epoch [17/50], Loss: 0.3598, Accuracy: 86.73%, Test Loss: 0.4354, Test Accuracy: 84.87%
# MoE Epoch [18/50], Loss: 0.3590, Accuracy: 86.89%, Test Loss: 0.4256, Test Accuracy: 85.22%
# MoE Epoch [19/50], Loss: 0.3520, Accuracy: 86.95%, Test Loss: 0.4277, Test Accuracy: 84.91%
# MoE Epoch [20/50], Loss: 0.3494, Accuracy: 87.13%, Test Loss: 0.4374, Test Accuracy: 84.91%
# MoE Epoch [21/50], Loss: 0.3501, Accuracy: 87.07%, Test Loss: 0.4216, Test Accuracy: 84.82%
# MoE Epoch [22/50], Loss: 0.3487, Accuracy: 87.13%, Test Loss: 0.4263, Test Accuracy: 85.28%
# MoE Epoch [23/50], Loss: 0.3427, Accuracy: 87.35%, Test Loss: 0.4561, Test Accuracy: 84.21%
# MoE Epoch [24/50], Loss: 0.3537, Accuracy: 86.99%, Test Loss: 0.4313, Test Accuracy: 84.97%
# MoE Epoch [25/50], Loss: 0.3420, Accuracy: 87.48%, Test Loss: 0.4326, Test Accuracy: 85.25%
# MoE Epoch [26/50], Loss: 0.3374, Accuracy: 87.60%, Test Loss: 0.4417, Test Accuracy: 84.44%
# MoE Epoch [27/50], Loss: 0.3407, Accuracy: 87.41%, Test Loss: 0.4181, Test Accuracy: 85.21%
# MoE Epoch [28/50], Loss: 0.3297, Accuracy: 87.93%, Test Loss: 0.4168, Test Accuracy: 85.79%
# MoE Epoch [29/50], Loss: 0.3324, Accuracy: 87.73%, Test Loss: 0.4251, Test Accuracy: 85.33%
# MoE Epoch [30/50], Loss: 0.3333, Accuracy: 87.75%, Test Loss: 0.4322, Test Accuracy: 84.85%
# MoE Epoch [31/50], Loss: 0.3311, Accuracy: 87.67%, Test Loss: 0.4227, Test Accuracy: 85.36%
# MoE Epoch [32/50], Loss: 0.3253, Accuracy: 88.00%, Test Loss: 0.4431, Test Accuracy: 84.83%
# MoE Epoch [33/50], Loss: 0.3338, Accuracy: 87.71%, Test Loss: 0.4385, Test Accuracy: 84.90%
# MoE Epoch [34/50], Loss: 0.3317, Accuracy: 87.75%, Test Loss: 0.4264, Test Accuracy: 85.37%
# MoE Epoch [35/50], Loss: 0.3259, Accuracy: 87.96%, Test Loss: 0.4205, Test Accuracy: 85.64%
# MoE Epoch [36/50], Loss: 0.3212, Accuracy: 88.06%, Test Loss: 0.4130, Test Accuracy: 85.37%
# MoE Epoch [37/50], Loss: 0.3192, Accuracy: 88.15%, Test Loss: 0.4436, Test Accuracy: 85.34%
# MoE Epoch [38/50], Loss: 0.3207, Accuracy: 88.11%, Test Loss: 0.4272, Test Accuracy: 85.77%
# MoE Epoch [39/50], Loss: 0.3166, Accuracy: 88.23%, Test Loss: 0.4233, Test Accuracy: 85.55%
# MoE Epoch [40/50], Loss: 0.3151, Accuracy: 88.27%, Test Loss: 0.4327, Test Accuracy: 85.50%
# MoE Epoch [41/50], Loss: 0.3149, Accuracy: 88.29%, Test Loss: 0.4382, Test Accuracy: 85.62%
# MoE Epoch [42/50], Loss: 0.3105, Accuracy: 88.48%, Test Loss: 0.4326, Test Accuracy: 85.37%
# MoE Epoch [43/50], Loss: 0.3169, Accuracy: 88.20%, Test Loss: 0.4287, Test Accuracy: 85.44%
# MoE Epoch [44/50], Loss: 0.3112, Accuracy: 88.53%, Test Loss: 0.4326, Test Accuracy: 85.44%
# MoE Epoch [45/50], Loss: 0.3131, Accuracy: 88.38%, Test Loss: 0.4480, Test Accuracy: 84.52%
# MoE Epoch [46/50], Loss: 0.3048, Accuracy: 88.81%, Test Loss: 0.4262, Test Accuracy: 85.77%
# MoE Epoch [47/50], Loss: 0.3039, Accuracy: 88.70%, Test Loss: 0.4355, Test Accuracy: 85.47%
# MoE Epoch [48/50], Loss: 0.3022, Accuracy: 88.81%, Test Loss: 0.4295, Test Accuracy: 85.72%
# MoE Epoch [49/50], Loss: 0.3049, Accuracy: 88.64%, Test Loss: 0.4509, Test Accuracy: 85.31%
# MoE Epoch [50/50], Loss: 0.3082, Accuracy: 88.57%, Test Loss: 0.4324, Test Accuracy: 85.75%

# %% [markdown]
# Plot comparision

# %%
# Plot comparison
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.plot(moe_train_accuracies, label='MoE Train')
plt.plot(moe_test_accuracies, label='MoE Test')
plt.title('Accuracy Comparison')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(moe_train_losses, label='MoE Train')
plt.plot(moe_test_losses, label='MoE Test')
plt.title('Loss Comparison')
plt.legend()

plt.show()

# Specify the file name
file_name = 'Sparse_MoE_results.txt'

# Open the file in write mode
with open(file_name, 'w') as file:
    # Write each value to the file, one per line
    file.write(f"spares_train_accs {moe_train_accuracies}\n")
    file.write(f"spares_test_accs {moe_test_accuracies}\n")
    file.write(f"spares_train_loss {moe_train_losses}\n")
    file.write(f"spares_test_loss {moe_test_losses}\n")

print(f"Array values have been successfully written to {file_name}")
# Out:
# Array values have been successfully written to Sparse_MoE_results.txt
